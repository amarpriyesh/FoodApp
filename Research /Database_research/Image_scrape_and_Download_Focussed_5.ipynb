# %% [markdown]
# <a href="https://colab.research.google.com/github/Stealth-Food-Exploration/web-application/blob/main/Research%20/Database_research/mage_scrape_and_Download_Focussed_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
from threading import Thread
from bing_image_downloader import downloader

# %%
def download_1000(query):
    downloader.download(query, limit=1000, output_dir='dataset', adult_filter_off=True, force_replace=False,
                        timeout=60)

# %% [markdown]
# ## Multithreaded approach to download images from Bing

# %%
queries = ['Chicken_tikka_masala', 'Paneer_butter_masala','Samosa','Naan','Dal_makhani']

T = []
for query in queries:
    t = Thread(target=download_1000, args=(query,))
    T.append(t)
    t.start()

for t in T:
    t.join()

# %%
for t in T:
    t.join()

# %%
# !cp -r "/content/dataset" "/content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5"

# %% [markdown]
# ## Cleanup to delete folder and files

# %%
import os
import shutil
def delete_folder_contents(folder_path):
    # Check if the folder exists
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' does not exist.")
        return

    # Iterate over the files in the folder and delete them
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        try:
            if os.path.isfile(file_path):
                os.remove(file_path)
            elif os.path.isdir(file_path):
                shutil.rmtree(file_path)
        except Exception as e:
            print(f"Failed to delete {file_path}: {e}")

    print(f"All files in '{folder_path}' have been deleted.")

def delete_folder(folder_path):
    # Check if the folder exists
    if not os.path.exists(folder_path):
        print(f"Folder '{folder_path}' does not exist.")
        return

    try:
        shutil.rmtree(folder_path)
        print(f"Folder '{folder_path}' has been deleted.")
    except Exception as e:
        print(f"Failed to delete folder '{folder_path}': {e}")

# Example usage:
folder_path = "/content/dataset"  # Change this to your folder path
delete_folder_contents(folder_path)
delete_folder(folder_path)
# Out:
# All files in '/content/dataset' have been deleted.
# Folder '/content/dataset' has been deleted.

# %% [markdown]
# ## Connect to GCP and authenticate

# %%
from google.colab import auth
auth.authenticate_user()

# %% [markdown]
# ## Select Bucket and Project in GCP

# %%
project_id = 'indian-food-exploration'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://foor-bucket-1/

# %% [markdown]
# ## Copy Data from Drive to GCP

# %%
bucket_name = 'foor-bucket-1'

# !gsutil -m cp -r /content/drive/MyDrive/GARAM\ food\ exploaration/Indian\ Food\ Exploration\ App/classimages_focused5 gs://{bucket_name}/
# Out:
# Copying file:///content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5/Samosa/Image_3.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5/Samosa/Image_5.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5/Samosa/Image_1.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5/Samosa/Image_4.jpg [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5/Samosa/Image_2.JPG [Content-Type=image/jpeg]...
# Copying file:///content/drive/MyDrive/GARAM food exploaration/Indian Food Exploration App/classimages_focused5/Samosa/Image_6.jpg [Content-Type=image/jpeg]...
# ...
